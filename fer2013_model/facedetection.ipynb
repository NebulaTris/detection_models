# %%
import tensorflow as tf
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
img_array = cv2.imread(r"fer2013_model/train/1/Training_3908.jpg")

# %%
img_array.shape
# Out:
# (48, 48, 3)

# %%
plt.imshow(img_array)

# %%
Datadirectory = r"fer2013_model/train/"

# %%
Class_1 = ["1"]

# %%
Class_2 = ["2"]

# %%
Class_3 = ["3"]

# %%
Class_4 = ["4"]

# %%
Class_5 = ["5"]

# %%
Class_6 = ["6"]

# %%
Class_7 = ["7"]

# %%
for category in Class_1:
    path = os.path.join(Datadirectory, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size = 224
new_array = cv2.resize(img_array, (img_size,img_size))
plt.imshow(cv2.cvtColor(new_array, cv2.COLOR_BGR2RGB))
plt.show()

# %%
for category in Class_2:
    path = os.path.join(Datadirectory, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size = 224
new_array = cv2.resize(img_array, (img_size,img_size))
plt.imshow(cv2.cvtColor(new_array, cv2.COLOR_BGR2RGB))
plt.show()

# %%
for category in Class_3:
    path = os.path.join(Datadirectory, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size = 224
new_array = cv2.resize(img_array, (img_size,img_size))
plt.imshow(cv2.cvtColor(new_array, cv2.COLOR_BGR2RGB))
plt.show()

# %%
for category in Class_4:
    path = os.path.join(Datadirectory, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size = 224
new_array = cv2.resize(img_array, (img_size,img_size))
plt.imshow(cv2.cvtColor(new_array, cv2.COLOR_BGR2RGB))
plt.show()

# %%
for category in Class_5:
    path = os.path.join(Datadirectory, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size = 224
new_array = cv2.resize(img_array, (img_size,img_size))
plt.imshow(cv2.cvtColor(new_array, cv2.COLOR_BGR2RGB))
plt.show()

# %%
for category in Class_6:
    path = os.path.join(Datadirectory, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size = 224
new_array = cv2.resize(img_array, (img_size,img_size))
plt.imshow(cv2.cvtColor(new_array, cv2.COLOR_BGR2RGB))
plt.show()

# %%
for category in Class_7:
    path = os.path.join(Datadirectory, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size = 224
new_array = cv2.resize(img_array, (img_size,img_size))
plt.imshow(cv2.cvtColor(new_array, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# # Read all the images and convert them into array

# %%
tD_1 = []

def ctD_1():
    for category in Class_1:
        path = os.path.join(Datadirectory, category)
        class_num = Class_1.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (img_size, img_size))
                tD_1.append([new_array,class_num])
            except Exception as e:
                pass

# %%
tD_2 = []

def ctD_2():
    for category in Class_2:
        path = os.path.join(Datadirectory, category)
        class_num = Class_2.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (img_size, img_size))
                tD_2.append([new_array,class_num])
            except Exception as e:
                pass

# %%
tD_3 = []

def ctD_3():
    for category in Class_3:
        path = os.path.join(Datadirectory, category)
        class_num = Class_3.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (img_size, img_size))
                tD_3.append([new_array,class_num])
            except Exception as e:
                pass

# %%
tD_4 = []

def ctD_4():
    for category in Class_4:
        path = os.path.join(Datadirectory, category)
        class_num = Class_4.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (img_size, img_size))
                tD_4.append([new_array,class_num])
            except Exception as e:
                pass

# %%
tD_5 = []

def ctD_5():
    for category in Class_5:
        path = os.path.join(Datadirectory, category)
        class_num = Class_5.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (img_size, img_size))
                tD_5.append([new_array,class_num])
            except Exception as e:
                pass

# %%
tD_6 = []

def ctD_6():
    for category in Class_6:
        path = os.path.join(Datadirectory, category)
        class_num = Class_6.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (img_size, img_size))
                tD_6.append([new_array,class_num])
            except Exception as e:
                pass

# %%
tD_7 = []

def ctD_7():
    for category in Class_7:
        path = os.path.join(Datadirectory, category)
        class_num = Class_7.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))
                new_array = cv2.resize(img_array, (img_size, img_size))
                tD_7.append([new_array,class_num])
            except Exception as e:
                pass

# %%
ctD_1()
ctD_2()
ctD_3()
ctD_4()
ctD_5()
ctD_6()
ctD_7()

# %%
print(len(tD_1))
print(len(tD_2))
print(len(tD_3))
print(len(tD_4))
print(len(tD_5))
print(len(tD_6))
print(len(tD_7))
# Out:
# 7990
# 872
# 8194
# 14430
# 9660
# 6342
# 9930

# %%
import random
random.shuffle(tD_1)
random.shuffle(tD_2)
random.shuffle(tD_3)
random.shuffle(tD_4)
random.shuffle(tD_5)
random.shuffle(tD_6)
random.shuffle(tD_7)

# %%
x = []
y = []

for features,label in tD_1:
    x.append(features)
    y.append(label)
    
x = np.array(x).reshape(-1, img_size, img_size, 3)

# %%
p = []
q = []

for features,label in tD_2:
    p.append(features)
    q.append(label)
    
p = np.array(p).reshape(-1, img_size, img_size, 3)

# %%
a = []
b = []

for features,label in tD_3:
    a.append(features)
    b.append(label)
    
a = np.array(a).reshape(-1, img_size, img_size, 3)

# %%
r = []
s = []

for features,label in tD_4:
    r.append(features)
    s.append(label)
    
r = np.array(r).reshape(-1, img_size, img_size, 3)

# %%
t = []
u = []

for features,label in tD_5:
    t.append(features)
    u.append(label)
    
t = np.array(t).reshape(-1, img_size, img_size, 3)

# %%
v = []
w = []

for features,label in tD_6:
    v.append(features)
    w.append(label)
    
v = np.array(v).reshape(-1, img_size, img_size, 3)

# %%
c = []
d = []

for features,label in tD_7:
    c.append(features)
    d.append(label)
    
c = np.array(c).reshape(-1, img_size, img_size, 3)

# %%
x.shape
# Out:
# (7990, 224, 224, 3)

# %%
p.shape
# Out:
# (872, 224, 224, 3)

# %%
a.shape
# Out:
# (8194, 224, 224, 3)

# %%
r.shape
# Out:
# (14430, 224, 224, 3)

# %%
t.shape
# Out:
# (9660, 224, 224, 3)

# %%
v.shape
# Out:
# (6342, 224, 224, 3)

# %%
c.shape
# Out:
# (9930, 224, 224, 3)

# %%
x = x/255.0;
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 x = x/255.0
#
# MemoryError: Unable to allocate 8.96 GiB for an array with shape (7990, 224, 224, 3) and data type float64

# %%
p = p/255.0;

# %%
a = a/255.0;
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 a = a/255.0
#
# MemoryError: Unable to allocate 9.19 GiB for an array with shape (8194, 224, 224, 3) and data type float64

# %%
r = r/255.0;
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 r = r/255.0
#
# MemoryError: Unable to allocate 16.2 GiB for an array with shape (14430, 224, 224, 3) and data type float64

# %%
t = t/255.0;
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[173], line 1
# ----> 1 t = t/255.0
#
# MemoryError: Unable to allocate 10.8 GiB for an array with shape (9660, 224, 224, 3) and data type float64

# %%
v = v/255.0;
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[174], line 1
# ----> 1 v = v/255.0
#
# MemoryError: Unable to allocate 7.11 GiB for an array with shape (6342, 224, 224, 3) and data type float64

# %%
c = c/255.0;

# %%
Y= np.array(y)

# %%
Y.shape

# %%
Q= np.array(q)

# %%
Q.shape

# %%
B= np.array(b)

# %%
B.shape

# %%
S= np.array(s)

# %%
S.shape

# %%
U= np.array(u)

# %%
U.shape

# %%
W= np.array(w)

# %%
W.shape

# %%
D= np.array(d)

# %%
D.shape

# %% [markdown]
# # Deep learning model for training - Transfer Learning
