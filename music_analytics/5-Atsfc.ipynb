# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
SPOTIPY_CLIENT_ID='fcbb0f29936b4f8ba90c4a606e516a67'
SPOTIPY_CLIENT_SECRET='9b66b9a7c4ec4f2ba5fe21b6575da778'

# %%
auth_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
artist_name = 'Led Zeppelin'

# %% [markdown]
# # Searching Artist

# %%
artists = sp.search(q='artist:'+artist_name,type='artist', limit=10)

# %%
artists
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=artist%3ALed+Zeppelin&type=artist&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'followers': {'href': None, 'total': 13552805},
#     'genres': ['album rock', 'classic rock', 'hard rock', 'rock'],
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'images': [{'height': 600,
#       'url': 'https://i.scdn.co/image/207803ce008388d3427a685254f9de6a8f61dc2e',
#       'width': 600},
#      {'height': 200,
#       'url': 'https://i.scdn.co/image/b0248a44865493e6a03832aa89854ada16ff07a8',
#       'width': 200},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/16eb3cdae0d824b520ac17710e943a99d3ef6602',
#       'width': 64}],
#     'name': 'Led Zeppelin',
#     'popularity': 75,
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0M5duvEaHQtnm2tvL4PmgF'},
#     'followers': {'href': None, 'total': 13},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0M5duvEaHQtnm2tvL4PmgF',
#     'id': '0M5duvEaHQtnm2tvL4PmgF',
#     'images': [],
#     'name': 'Led Zeppelin',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:0M5duvEaHQtnm2tvL4PmgF'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0xNrQovaLnM8VBUgMb3wlA'},
#     'followers': {'href': None, 'total': 1571},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/0xNrQovaLnM8VBUgMb3wlA',
#     'id': '0xNrQovaLnM8VBUgMb3wlA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb7a5c39def11a195badd5c776',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051747a5c39def11a195badd5c776',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1787a5c39def11a195badd5c776',
#       'width': 160}],
#     'name': 'In The Light of Led Zeppelin',
#     'popularity': 1,
#     'type': 'artist',
#     'uri': 'spotify:artist:0xNrQovaLnM8VBUgMb3wlA'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ChaTST0oG5o9vOsdsKydL'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6ChaTST0oG5o9vOsdsKydL',
#     'id': '6ChaTST0oG5o9vOsdsKydL',
#     'images': [],
#     'name': 'karaoke - Led Zeppelin',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:6ChaTST0oG5o9vOsdsKydL'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Rh2QaSt4mtaaIoUatPAXP'},
#     'followers': {'href': None, 'total': 266},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2Rh2QaSt4mtaaIoUatPAXP',
#     'id': '2Rh2QaSt4mtaaIoUatPAXP',
#     'images': [],
#     'name': 'Led Zeppelin Jam',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:2Rh2QaSt4mtaaIoUatPAXP'}],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 5}}

# %%
artists['artists']['items']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#   'followers': {'href': None, 'total': 13552805},
#   'genres': ['album rock', 'classic rock', 'hard rock', 'rock'],
#   'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#   'id': '36QJpDe2go2KgaRleHCDTp',
#   'images': [{'height': 600,
#     'url': 'https://i.scdn.co/image/207803ce008388d3427a685254f9de6a8f61dc2e',
#     'width': 600},
#    {'height': 200,
#     'url': 'https://i.scdn.co/image/b0248a44865493e6a03832aa89854ada16ff07a8',
#     'width': 200},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/16eb3cdae0d824b520ac17710e943a99d3ef6602',
#     'width': 64}],
#   'name': 'Led Zeppelin',
#   'popularity': 75,
#   'type': 'artist',
#   'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0M5duvEaHQtnm2tvL4PmgF'},
#   'followers': {'href': None, 'total': 13},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/0M5duvEaHQtnm2tvL4PmgF',
#   'id': '0M5duvEaHQtnm2tvL4PmgF',
#   'images': [],
#   'name': 'Led Zeppelin',
#   'popularity': 1,
#   'type': 'artist',
#   'uri': 'spotify:artist:0M5duvEaHQtnm2tvL4PmgF'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0xNrQovaLnM8VBUgMb3wlA'},
#   'followers': {'href': None, 'total': 1571},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/0xNrQovaLnM8VBUgMb3wlA',
#   'id': '0xNrQovaLnM8VBUgMb3wlA',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb7a5c39def11a195badd5c776',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051747a5c39def11a195badd5c776',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1787a5c39def11a195badd5c776',
#     'width': 160}],
#   'name': 'In The Light of Led Zeppelin',
#   'popularity': 1,
#   'type': 'artist',
#   'uri': 'spotify:artist:0xNrQovaLnM8VBUgMb3wlA'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/6ChaTST0oG5o9vOsdsKydL'},
#   'followers': {'href': None, 'total': 0},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/6ChaTST0oG5o9vOsdsKydL',
#   'id': '6ChaTST0oG5o9vOsdsKydL',
#   'images': [],
#   'name': 'karaoke - Led Zeppelin',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:6ChaTST0oG5o9vOsdsKydL'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Rh2QaSt4mtaaIoUatPAXP'},
#   'followers': {'href': None, 'total': 266},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/2Rh2QaSt4mtaaIoUatPAXP',
#   'id': '2Rh2QaSt4mtaaIoUatPAXP',
#   'images': [],
#   'name': 'Led Zeppelin Jam',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:2Rh2QaSt4mtaaIoUatPAXP'}]

# %%
artists['artists']['items'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#  'followers': {'href': None, 'total': 13552805},
#  'genres': ['album rock', 'classic rock', 'hard rock', 'rock'],
#  'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#  'id': '36QJpDe2go2KgaRleHCDTp',
#  'images': [{'height': 600,
#    'url': 'https://i.scdn.co/image/207803ce008388d3427a685254f9de6a8f61dc2e',
#    'width': 600},
#   {'height': 200,
#    'url': 'https://i.scdn.co/image/b0248a44865493e6a03832aa89854ada16ff07a8',
#    'width': 200},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/16eb3cdae0d824b520ac17710e943a99d3ef6602',
#    'width': 64}],
#  'name': 'Led Zeppelin',
#  'popularity': 75,
#  'type': 'artist',
#  'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}

# %%
artist_uri = artists['artists']['items'][0]['uri']
print(artist_uri)
# Out:
# spotify:artist:36QJpDe2go2KgaRleHCDTp

# %%
results = sp.artist_top_tracks(artist_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('track id : ' + track['id'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Stairway to Heaven - Remaster
# track id : 5CQ30WqJwcep0pYcV4AMNc
# audio    : https://p.scdn.co/mp3-preview/337c8d45ac66899bc2db9ef3ed9438fe1d035ab1?cid=fcbb0f29936b4f8ba90c4a606e516a67
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Immigrant Song - Remaster
# track id : 78lgmZwycJ3nzsdgmPPGNx
# audio    : https://p.scdn.co/mp3-preview/f50f3416ea0807503e172ba87a92d8047d4f95da?cid=fcbb0f29936b4f8ba90c4a606e516a67
# cover art: https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb
#
# track    : Whole Lotta Love - 1990 Remaster
# track id : 0hCB0YR03f6AmQaHbwWDe8
# audio    : https://p.scdn.co/mp3-preview/89f3dc45265602fa874c23d638538af0f2c6b56a?cid=fcbb0f29936b4f8ba90c4a606e516a67
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Black Dog - Remaster
# track id : 3qT4bUD1MaWpGrTwcvguhb
# audio    : https://p.scdn.co/mp3-preview/78dd352fdbe8d2a867b72c5a71ac44ef6a462ab4?cid=fcbb0f29936b4f8ba90c4a606e516a67
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Rock and Roll - Remaster
# track id : 4PRGxHpCpF2yoOHYKQIEwD
# audio    : https://p.scdn.co/mp3-preview/9464a064068943a58f673035d9ebe58e98f46bea?cid=fcbb0f29936b4f8ba90c4a606e516a67
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Good Times Bad Times - 1993 Remaster
# track id : 0QwZfbw26QeUoIy82Z2jYp
# audio    : https://p.scdn.co/mp3-preview/499f6278a140080d3218c448448d0eb149eb65b7?cid=fcbb0f29936b4f8ba90c4a606e516a67
# cover art: https://i.scdn.co/image/ab67616d0000b2736f2f499c1df1f210c9b34b32
#
# track    : Ramble On - 1990 Remaster
# track id : 3MODES4TNtygekLl146Dxd
# audio    : https://p.scdn.co/mp3-preview/e734d4e4f125ff5fbe7d69faa7d505dc744fb7bb?cid=fcbb0f29936b4f8ba90c4a606e516a67
# cover art: https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d
#
# track    : Going to California - Remaster
# track id : 70gbuMqwNBE2Y5rkQJE9By
# audio    : https://p.scdn.co/mp3-preview/8c2452c1db9c3a7aad2b826cb52303a689814f6e?cid=fcbb0f29936b4f8ba90c4a606e516a67
# cover art: https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69
#
# track    : Kashmir - Remaster
# track id : 6Vjk8MNXpQpi0F4BefdTyq
# audio    : https://p.scdn.co/mp3-preview/4d9bde799eec8913e53c184c45b9fd575690b917?cid=fcbb0f29936b4f8ba90c4a606e516a67
# cover art: https://i.scdn.co/image/ab67616d0000b273765b0617b572bdd1dbdc7d8e
#
# track    : Over the Hills and Far Away - Remaster
# track id : 2eDdFHgqNJltzlvlZFVDWd
# audio    : https://p.scdn.co/mp3-preview/a828935e429be801aa374eeeb8b2cb0d91755d57?cid=fcbb0f29936b4f8ba90c4a606e516a67
# cover art: https://i.scdn.co/image/ab67616d0000b2731aa47e71c4edfeaddb65cd54

# %%
results
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#     'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#     'id': '44Ig8dzqOkvkGDzaUof9lK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Led Zeppelin IV (Deluxe Edition)',
#     'release_date': '1971-11-08',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:44Ig8dzqOkvkGDzaUof9lK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'disc_number': 1,
#    'duration_ms': 482830,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21300959'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5CQ30WqJwcep0pYcV4AMNc'},
#    'href': 'https://api.spotify.com/v1/tracks/5CQ30WqJwcep0pYcV4AMNc',
#    'id': '5CQ30WqJwcep0pYcV4AMNc',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Stairway to Heaven - Remaster',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/337c8d45ac66899bc2db9ef3ed9438fe1d035ab1?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:5CQ30WqJwcep0pYcV4AMNc'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6P5QHz4XtxOmS5EuiGIPut'},
#     'href': 'https://api.spotify.com/v1/albums/6P5QHz4XtxOmS5EuiGIPut',
#     'id': '6P5QHz4XtxOmS5EuiGIPut',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0290a50cfe99a4c19ff3cbfbdb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485190a50cfe99a4c19ff3cbfbdb',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Led Zeppelin III (Remaster)',
#     'release_date': '1970',
#     'release_date_precision': 'year',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:6P5QHz4XtxOmS5EuiGIPut'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'disc_number': 1,
#    'duration_ms': 146250,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21300934'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/78lgmZwycJ3nzsdgmPPGNx'},
#    'href': 'https://api.spotify.com/v1/tracks/78lgmZwycJ3nzsdgmPPGNx',
#    'id': '78lgmZwycJ3nzsdgmPPGNx',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Immigrant Song - Remaster',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f50f3416ea0807503e172ba87a92d8047d4f95da?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:78lgmZwycJ3nzsdgmPPGNx'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/70lQYZtypdCALtFVlQAcvx'},
#     'href': 'https://api.spotify.com/v1/albums/70lQYZtypdCALtFVlQAcvx',
#     'id': '70lQYZtypdCALtFVlQAcvx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fc4f17340773c6c3579fea0d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fc4f17340773c6c3579fea0d',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Led Zeppelin II (1994 Remaster)',
#     'release_date': '1969-10-22',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:70lQYZtypdCALtFVlQAcvx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'disc_number': 1,
#    'duration_ms': 333893,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT29900471'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0hCB0YR03f6AmQaHbwWDe8'},
#    'href': 'https://api.spotify.com/v1/tracks/0hCB0YR03f6AmQaHbwWDe8',
#    'id': '0hCB0YR03f6AmQaHbwWDe8',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Whole Lotta Love - 1990 Remaster',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/89f3dc45265602fa874c23d638538af0f2c6b56a?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0hCB0YR03f6AmQaHbwWDe8'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#     'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#     'id': '44Ig8dzqOkvkGDzaUof9lK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Led Zeppelin IV (Deluxe Edition)',
#     'release_date': '1971-11-08',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:44Ig8dzqOkvkGDzaUof9lK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'disc_number': 1,
#    'duration_ms': 295386,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21300956'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3qT4bUD1MaWpGrTwcvguhb'},
#    'href': 'https://api.spotify.com/v1/tracks/3qT4bUD1MaWpGrTwcvguhb',
#    'id': '3qT4bUD1MaWpGrTwcvguhb',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Black Dog - Remaster',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/78dd352fdbe8d2a867b72c5a71ac44ef6a462ab4?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3qT4bUD1MaWpGrTwcvguhb'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#     'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#     'id': '44Ig8dzqOkvkGDzaUof9lK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Led Zeppelin IV (Deluxe Edition)',
#     'release_date': '1971-11-08',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:44Ig8dzqOkvkGDzaUof9lK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'disc_number': 1,
#    'duration_ms': 220560,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21300957'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4PRGxHpCpF2yoOHYKQIEwD'},
#    'href': 'https://api.spotify.com/v1/tracks/4PRGxHpCpF2yoOHYKQIEwD',
#    'id': '4PRGxHpCpF2yoOHYKQIEwD',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Rock and Roll - Remaster',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9464a064068943a58f673035d9ebe58e98f46bea?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:4PRGxHpCpF2yoOHYKQIEwD'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3ycjBixZf7S3WpC5WZhhUK'},
#     'href': 'https://api.spotify.com/v1/albums/3ycjBixZf7S3WpC5WZhhUK',
#     'id': '3ycjBixZf7S3WpC5WZhhUK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736f2f499c1df1f210c9b34b32',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026f2f499c1df1f210c9b34b32',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516f2f499c1df1f210c9b34b32',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Led Zeppelin',
#     'release_date': '1969-01-12',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:3ycjBixZf7S3WpC5WZhhUK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'disc_number': 1,
#    'duration_ms': 166266,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT29900534'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0QwZfbw26QeUoIy82Z2jYp'},
#    'href': 'https://api.spotify.com/v1/tracks/0QwZfbw26QeUoIy82Z2jYp',
#    'id': '0QwZfbw26QeUoIy82Z2jYp',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Good Times Bad Times - 1993 Remaster',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/499f6278a140080d3218c448448d0eb149eb65b7?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0QwZfbw26QeUoIy82Z2jYp'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/70lQYZtypdCALtFVlQAcvx'},
#     'href': 'https://api.spotify.com/v1/albums/70lQYZtypdCALtFVlQAcvx',
#     'id': '70lQYZtypdCALtFVlQAcvx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fc4f17340773c6c3579fea0d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fc4f17340773c6c3579fea0d',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Led Zeppelin II (1994 Remaster)',
#     'release_date': '1969-10-22',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:70lQYZtypdCALtFVlQAcvx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'disc_number': 1,
#    'duration_ms': 263333,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT29900477'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3MODES4TNtygekLl146Dxd'},
#    'href': 'https://api.spotify.com/v1/tracks/3MODES4TNtygekLl146Dxd',
#    'id': '3MODES4TNtygekLl146Dxd',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ramble On - 1990 Remaster',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e734d4e4f125ff5fbe7d69faa7d505dc744fb7bb?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:3MODES4TNtygekLl146Dxd'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#     'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#     'id': '44Ig8dzqOkvkGDzaUof9lK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Led Zeppelin IV (Deluxe Edition)',
#     'release_date': '1971-11-08',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:44Ig8dzqOkvkGDzaUof9lK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'disc_number': 1,
#    'duration_ms': 212160,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21300962'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/70gbuMqwNBE2Y5rkQJE9By'},
#    'href': 'https://api.spotify.com/v1/tracks/70gbuMqwNBE2Y5rkQJE9By',
#    'id': '70gbuMqwNBE2Y5rkQJE9By',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Going to California - Remaster',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8c2452c1db9c3a7aad2b826cb52303a689814f6e?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:70gbuMqwNBE2Y5rkQJE9By'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/26tH0kjUhkxBEd3ipGkx3Y'},
#     'href': 'https://api.spotify.com/v1/albums/26tH0kjUhkxBEd3ipGkx3Y',
#     'id': '26tH0kjUhkxBEd3ipGkx3Y',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273765b0617b572bdd1dbdc7d8e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02765b0617b572bdd1dbdc7d8e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851765b0617b572bdd1dbdc7d8e',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Physical Graffiti (Deluxe Edition)',
#     'release_date': '1975-02-24',
#     'release_date_precision': 'day',
#     'total_tracks': 22,
#     'type': 'album',
#     'uri': 'spotify:album:26tH0kjUhkxBEd3ipGkx3Y'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'disc_number': 1,
#    'duration_ms': 517125,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21300969'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Vjk8MNXpQpi0F4BefdTyq'},
#    'href': 'https://api.spotify.com/v1/tracks/6Vjk8MNXpQpi0F4BefdTyq',
#    'id': '6Vjk8MNXpQpi0F4BefdTyq',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Kashmir - Remaster',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4d9bde799eec8913e53c184c45b9fd575690b917?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:6Vjk8MNXpQpi0F4BefdTyq'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#       'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#       'id': '36QJpDe2go2KgaRleHCDTp',
#       'name': 'Led Zeppelin',
#       'type': 'artist',
#       'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0GqpoHJREPp0iuXK3HzrHk'},
#     'href': 'https://api.spotify.com/v1/albums/0GqpoHJREPp0iuXK3HzrHk',
#     'id': '0GqpoHJREPp0iuXK3HzrHk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731aa47e71c4edfeaddb65cd54',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021aa47e71c4edfeaddb65cd54',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511aa47e71c4edfeaddb65cd54',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Houses of the Holy (Remaster)',
#     'release_date': '1973-03-28',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:0GqpoHJREPp0iuXK3HzrHk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'disc_number': 1,
#    'duration_ms': 290933,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21300892'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2eDdFHgqNJltzlvlZFVDWd'},
#    'href': 'https://api.spotify.com/v1/tracks/2eDdFHgqNJltzlvlZFVDWd',
#    'id': '2eDdFHgqNJltzlvlZFVDWd',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Over the Hills and Far Away - Remaster',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a828935e429be801aa374eeeb8b2cb0d91755d57?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:2eDdFHgqNJltzlvlZFVDWd'}]}

# %%
results['tracks']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#    'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#    'id': '44Ig8dzqOkvkGDzaUof9lK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Led Zeppelin IV (Deluxe Edition)',
#    'release_date': '1971-11-08',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:44Ig8dzqOkvkGDzaUof9lK'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'disc_number': 1,
#   'duration_ms': 482830,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT21300959'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5CQ30WqJwcep0pYcV4AMNc'},
#   'href': 'https://api.spotify.com/v1/tracks/5CQ30WqJwcep0pYcV4AMNc',
#   'id': '5CQ30WqJwcep0pYcV4AMNc',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Stairway to Heaven - Remaster',
#   'popularity': 82,
#   'preview_url': 'https://p.scdn.co/mp3-preview/337c8d45ac66899bc2db9ef3ed9438fe1d035ab1?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:5CQ30WqJwcep0pYcV4AMNc'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6P5QHz4XtxOmS5EuiGIPut'},
#    'href': 'https://api.spotify.com/v1/albums/6P5QHz4XtxOmS5EuiGIPut',
#    'id': '6P5QHz4XtxOmS5EuiGIPut',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27390a50cfe99a4c19ff3cbfbdb',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0290a50cfe99a4c19ff3cbfbdb',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485190a50cfe99a4c19ff3cbfbdb',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Led Zeppelin III (Remaster)',
#    'release_date': '1970',
#    'release_date_precision': 'year',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:6P5QHz4XtxOmS5EuiGIPut'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'disc_number': 1,
#   'duration_ms': 146250,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT21300934'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/78lgmZwycJ3nzsdgmPPGNx'},
#   'href': 'https://api.spotify.com/v1/tracks/78lgmZwycJ3nzsdgmPPGNx',
#   'id': '78lgmZwycJ3nzsdgmPPGNx',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Immigrant Song - Remaster',
#   'popularity': 82,
#   'preview_url': 'https://p.scdn.co/mp3-preview/f50f3416ea0807503e172ba87a92d8047d4f95da?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:78lgmZwycJ3nzsdgmPPGNx'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/70lQYZtypdCALtFVlQAcvx'},
#    'href': 'https://api.spotify.com/v1/albums/70lQYZtypdCALtFVlQAcvx',
#    'id': '70lQYZtypdCALtFVlQAcvx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fc4f17340773c6c3579fea0d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fc4f17340773c6c3579fea0d',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Led Zeppelin II (1994 Remaster)',
#    'release_date': '1969-10-22',
#    'release_date_precision': 'day',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:70lQYZtypdCALtFVlQAcvx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'disc_number': 1,
#   'duration_ms': 333893,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT29900471'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0hCB0YR03f6AmQaHbwWDe8'},
#   'href': 'https://api.spotify.com/v1/tracks/0hCB0YR03f6AmQaHbwWDe8',
#   'id': '0hCB0YR03f6AmQaHbwWDe8',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Whole Lotta Love - 1990 Remaster',
#   'popularity': 79,
#   'preview_url': 'https://p.scdn.co/mp3-preview/89f3dc45265602fa874c23d638538af0f2c6b56a?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0hCB0YR03f6AmQaHbwWDe8'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#    'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#    'id': '44Ig8dzqOkvkGDzaUof9lK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Led Zeppelin IV (Deluxe Edition)',
#    'release_date': '1971-11-08',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:44Ig8dzqOkvkGDzaUof9lK'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'disc_number': 1,
#   'duration_ms': 295386,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT21300956'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3qT4bUD1MaWpGrTwcvguhb'},
#   'href': 'https://api.spotify.com/v1/tracks/3qT4bUD1MaWpGrTwcvguhb',
#   'id': '3qT4bUD1MaWpGrTwcvguhb',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Black Dog - Remaster',
#   'popularity': 76,
#   'preview_url': 'https://p.scdn.co/mp3-preview/78dd352fdbe8d2a867b72c5a71ac44ef6a462ab4?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3qT4bUD1MaWpGrTwcvguhb'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#    'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#    'id': '44Ig8dzqOkvkGDzaUof9lK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Led Zeppelin IV (Deluxe Edition)',
#    'release_date': '1971-11-08',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:44Ig8dzqOkvkGDzaUof9lK'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'disc_number': 1,
#   'duration_ms': 220560,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT21300957'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4PRGxHpCpF2yoOHYKQIEwD'},
#   'href': 'https://api.spotify.com/v1/tracks/4PRGxHpCpF2yoOHYKQIEwD',
#   'id': '4PRGxHpCpF2yoOHYKQIEwD',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Rock and Roll - Remaster',
#   'popularity': 75,
#   'preview_url': 'https://p.scdn.co/mp3-preview/9464a064068943a58f673035d9ebe58e98f46bea?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:4PRGxHpCpF2yoOHYKQIEwD'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3ycjBixZf7S3WpC5WZhhUK'},
#    'href': 'https://api.spotify.com/v1/albums/3ycjBixZf7S3WpC5WZhhUK',
#    'id': '3ycjBixZf7S3WpC5WZhhUK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2736f2f499c1df1f210c9b34b32',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e026f2f499c1df1f210c9b34b32',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048516f2f499c1df1f210c9b34b32',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Led Zeppelin',
#    'release_date': '1969-01-12',
#    'release_date_precision': 'day',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:3ycjBixZf7S3WpC5WZhhUK'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'disc_number': 1,
#   'duration_ms': 166266,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT29900534'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0QwZfbw26QeUoIy82Z2jYp'},
#   'href': 'https://api.spotify.com/v1/tracks/0QwZfbw26QeUoIy82Z2jYp',
#   'id': '0QwZfbw26QeUoIy82Z2jYp',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Good Times Bad Times - 1993 Remaster',
#   'popularity': 75,
#   'preview_url': 'https://p.scdn.co/mp3-preview/499f6278a140080d3218c448448d0eb149eb65b7?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0QwZfbw26QeUoIy82Z2jYp'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/70lQYZtypdCALtFVlQAcvx'},
#    'href': 'https://api.spotify.com/v1/albums/70lQYZtypdCALtFVlQAcvx',
#    'id': '70lQYZtypdCALtFVlQAcvx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fc4f17340773c6c3579fea0d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fc4f17340773c6c3579fea0d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fc4f17340773c6c3579fea0d',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Led Zeppelin II (1994 Remaster)',
#    'release_date': '1969-10-22',
#    'release_date_precision': 'day',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:70lQYZtypdCALtFVlQAcvx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'disc_number': 1,
#   'duration_ms': 263333,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT29900477'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3MODES4TNtygekLl146Dxd'},
#   'href': 'https://api.spotify.com/v1/tracks/3MODES4TNtygekLl146Dxd',
#   'id': '3MODES4TNtygekLl146Dxd',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Ramble On - 1990 Remaster',
#   'popularity': 75,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e734d4e4f125ff5fbe7d69faa7d505dc744fb7bb?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:3MODES4TNtygekLl146Dxd'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#    'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#    'id': '44Ig8dzqOkvkGDzaUof9lK',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Led Zeppelin IV (Deluxe Edition)',
#    'release_date': '1971-11-08',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:44Ig8dzqOkvkGDzaUof9lK'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'disc_number': 1,
#   'duration_ms': 212160,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT21300962'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/70gbuMqwNBE2Y5rkQJE9By'},
#   'href': 'https://api.spotify.com/v1/tracks/70gbuMqwNBE2Y5rkQJE9By',
#   'id': '70gbuMqwNBE2Y5rkQJE9By',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Going to California - Remaster',
#   'popularity': 73,
#   'preview_url': 'https://p.scdn.co/mp3-preview/8c2452c1db9c3a7aad2b826cb52303a689814f6e?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:70gbuMqwNBE2Y5rkQJE9By'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/26tH0kjUhkxBEd3ipGkx3Y'},
#    'href': 'https://api.spotify.com/v1/albums/26tH0kjUhkxBEd3ipGkx3Y',
#    'id': '26tH0kjUhkxBEd3ipGkx3Y',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273765b0617b572bdd1dbdc7d8e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02765b0617b572bdd1dbdc7d8e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851765b0617b572bdd1dbdc7d8e',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Physical Graffiti (Deluxe Edition)',
#    'release_date': '1975-02-24',
#    'release_date_precision': 'day',
#    'total_tracks': 22,
#    'type': 'album',
#    'uri': 'spotify:album:26tH0kjUhkxBEd3ipGkx3Y'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'disc_number': 1,
#   'duration_ms': 517125,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT21300969'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6Vjk8MNXpQpi0F4BefdTyq'},
#   'href': 'https://api.spotify.com/v1/tracks/6Vjk8MNXpQpi0F4BefdTyq',
#   'id': '6Vjk8MNXpQpi0F4BefdTyq',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Kashmir - Remaster',
#   'popularity': 73,
#   'preview_url': 'https://p.scdn.co/mp3-preview/4d9bde799eec8913e53c184c45b9fd575690b917?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:6Vjk8MNXpQpi0F4BefdTyq'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#      'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#      'id': '36QJpDe2go2KgaRleHCDTp',
#      'name': 'Led Zeppelin',
#      'type': 'artist',
#      'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0GqpoHJREPp0iuXK3HzrHk'},
#    'href': 'https://api.spotify.com/v1/albums/0GqpoHJREPp0iuXK3HzrHk',
#    'id': '0GqpoHJREPp0iuXK3HzrHk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731aa47e71c4edfeaddb65cd54',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021aa47e71c4edfeaddb65cd54',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511aa47e71c4edfeaddb65cd54',
#      'width': 64}],
#    'is_playable': True,
#    'name': 'Houses of the Holy (Remaster)',
#    'release_date': '1973-03-28',
#    'release_date_precision': 'day',
#    'total_tracks': 8,
#    'type': 'album',
#    'uri': 'spotify:album:0GqpoHJREPp0iuXK3HzrHk'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'disc_number': 1,
#   'duration_ms': 290933,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT21300892'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2eDdFHgqNJltzlvlZFVDWd'},
#   'href': 'https://api.spotify.com/v1/tracks/2eDdFHgqNJltzlvlZFVDWd',
#   'id': '2eDdFHgqNJltzlvlZFVDWd',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Over the Hills and Far Away - Remaster',
#   'popularity': 73,
#   'preview_url': 'https://p.scdn.co/mp3-preview/a828935e429be801aa374eeeb8b2cb0d91755d57?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:2eDdFHgqNJltzlvlZFVDWd'}]

# %%
len(results['tracks'])
# Out:
# 10

# %%
results['tracks'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#     'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#     'id': '36QJpDe2go2KgaRleHCDTp',
#     'name': 'Led Zeppelin',
#     'type': 'artist',
#     'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/44Ig8dzqOkvkGDzaUof9lK'},
#   'href': 'https://api.spotify.com/v1/albums/44Ig8dzqOkvkGDzaUof9lK',
#   'id': '44Ig8dzqOkvkGDzaUof9lK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c8a11e48c91a982d086afc69',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c8a11e48c91a982d086afc69',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c8a11e48c91a982d086afc69',
#     'width': 64}],
#   'is_playable': True,
#   'name': 'Led Zeppelin IV (Deluxe Edition)',
#   'release_date': '1971-11-08',
#   'release_date_precision': 'day',
#   'total_tracks': 16,
#   'type': 'album',
#   'uri': 'spotify:album:44Ig8dzqOkvkGDzaUof9lK'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/36QJpDe2go2KgaRleHCDTp'},
#    'href': 'https://api.spotify.com/v1/artists/36QJpDe2go2KgaRleHCDTp',
#    'id': '36QJpDe2go2KgaRleHCDTp',
#    'name': 'Led Zeppelin',
#    'type': 'artist',
#    'uri': 'spotify:artist:36QJpDe2go2KgaRleHCDTp'}],
#  'disc_number': 1,
#  'duration_ms': 482830,
#  'explicit': False,
#  'external_ids': {'isrc': 'USAT21300959'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/5CQ30WqJwcep0pYcV4AMNc'},
#  'href': 'https://api.spotify.com/v1/tracks/5CQ30WqJwcep0pYcV4AMNc',
#  'id': '5CQ30WqJwcep0pYcV4AMNc',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Stairway to Heaven - Remaster',
#  'popularity': 82,
#  'preview_url': 'https://p.scdn.co/mp3-preview/337c8d45ac66899bc2db9ef3ed9438fe1d035ab1?cid=fcbb0f29936b4f8ba90c4a606e516a67',
#  'track_number': 4,
#  'type': 'track',
#  'uri': 'spotify:track:5CQ30WqJwcep0pYcV4AMNc'}

# %%
print(results['tracks'][0]['id'])
print(results['tracks'][0]['popularity'])
print(results['tracks'][0]['name'])
print(results['tracks'][0]['album']['release_date'])
# Out:
# 5CQ30WqJwcep0pYcV4AMNc
# 82
# Stairway to Heaven - Remaster
# 1971-11-08

# %%
track_result = []
for i, item in enumerate(results['tracks']):
#     track = item['album']
    track_id = item['id']
    track_name = item['name']
    popularity = item['popularity']
    track_result.append((i, artist_name, track['name'], track_id, track_name, item['album']['release_date'], popularity))

# %%
track_result
# Out:
# [(0,
#   'Led Zeppelin',
#   'Over the Hills and Far Away - Remaster',
#   '5CQ30WqJwcep0pYcV4AMNc',
#   'Stairway to Heaven - Remaster',
#   '1971-11-08',
#   82),
#  (1,
#   'Led Zeppelin',
#   'Over the Hills and Far Away - Remaster',
#   '78lgmZwycJ3nzsdgmPPGNx',
#   'Immigrant Song - Remaster',
#   '1970',
#   82),
#  (2,
#   'Led Zeppelin',
#   'Over the Hills and Far Away - Remaster',
#   '0hCB0YR03f6AmQaHbwWDe8',
#   'Whole Lotta Love - 1990 Remaster',
#   '1969-10-22',
#   79),
#  (3,
#   'Led Zeppelin',
#   'Over the Hills and Far Away - Remaster',
#   '3qT4bUD1MaWpGrTwcvguhb',
#   'Black Dog - Remaster',
#   '1971-11-08',
#   76),
#  (4,
#   'Led Zeppelin',
#   'Over the Hills and Far Away - Remaster',
#   '4PRGxHpCpF2yoOHYKQIEwD',
#   'Rock and Roll - Remaster',
#   '1971-11-08',
#   75),
#  (5,
#   'Led Zeppelin',
#   'Over the Hills and Far Away - Remaster',
#   '0QwZfbw26QeUoIy82Z2jYp',
#   'Good Times Bad Times - 1993 Remaster',
#   '1969-01-12',
#   75),
#  (6,
#   'Led Zeppelin',
#   'Over the Hills and Far Away - Remaster',
#   '3MODES4TNtygekLl146Dxd',
#   'Ramble On - 1990 Remaster',
#   '1969-10-22',
#   75),
#  (7,
#   'Led Zeppelin',
#   'Over the Hills and Far Away - Remaster',
#   '70gbuMqwNBE2Y5rkQJE9By',
#   'Going to California - Remaster',
#   '1971-11-08',
#   73),
#  (8,
#   'Led Zeppelin',
#   'Over the Hills and Far Away - Remaster',
#   '6Vjk8MNXpQpi0F4BefdTyq',
#   'Kashmir - Remaster',
#   '1975-02-24',
#   73),
#  (9,
#   'Led Zeppelin',
#   'Over the Hills and Far Away - Remaster',
#   '2eDdFHgqNJltzlvlZFVDWd',
#   'Over the Hills and Far Away - Remaster',
#   '1973-03-28',
#   73)]

# %%
import pandas as pd

# %%
track_df = pd.DataFrame(track_result, index=None, columns=('Item', 'Artist', 'Album Name', 'Id', 'Song Name', 'Release Date', 'Popularity'))

# %%
track_df
# Out:
#    Item        Artist                              Album Name  \
# 0     0  Led Zeppelin  Over the Hills and Far Away - Remaster
# 1     1  Led Zeppelin  Over the Hills and Far Away - Remaster
# 2     2  Led Zeppelin  Over the Hills and Far Away - Remaster
# 3     3  Led Zeppelin  Over the Hills and Far Away - Remaster
# 4     4  Led Zeppelin  Over the Hills and Far Away - Remaster
# 5     5  Led Zeppelin  Over the Hills and Far Away - Remaster
# 6     6  Led Zeppelin  Over the Hills and Far Away - Remaster
# 7     7  Led Zeppelin  Over the Hills and Far Away - Remaster
# 8     8  Led Zeppelin  Over the Hills and Far Away - Remaster
# 9     9  Led Zeppelin  Over the Hills and Far Away - Remaster
#
#                        Id                               Song Name  \
# 0  5CQ30WqJwcep0pYcV4AMNc           Stairway to Heaven - Remaster
# 1  78lgmZwycJ3nzsdgmPPGNx               Immigrant Song - Remaster
# 2  0hCB0YR03f6AmQaHbwWDe8        Whole Lotta Love - 1990 Remaster
# 3  3qT4bUD1MaWpGrTwcvguhb                    Black Dog - Remaster
# 4  4PRGxHpCpF2yoOHYKQIEwD                Rock and Roll - Remaster
# 5  0QwZfbw26QeUoIy82Z2jYp    Good Times Bad Times - 1993 Remaster
# 6  3MODES4TNtygekLl146Dxd               Ramble On - 1990 Remaster
# 7  70gbuMqwNBE2Y5rkQJE9By          Going to California - Remaster
# 8  6Vjk8MNXpQpi0F4BefdTyq                      Kashmir - Remaster
# 9  2eDdFHgqNJltzlvlZFVDWd  Over the Hills and Far Away - Remaster
#
#   Release Date  Popularity
# 0   1971-11-08          82
# 1         1970          82
# 2   1969-10-22          79
# 3   1971-11-08          76
# 4   1971-11-08          75
# 5   1969-01-12          75
# 6   1969-10-22          75
# 7   1971-11-08          73
# 8   1975-02-24          73
# 9   1973-03-28          73

# %%
features_df = pd.DataFrame()
for id in track_df['Id'].iteritems():
    track_id = id[1]
    audio_features = sp.audio_features(track_id)
    local_features = pd.DataFrame(audio_features, index=[0])
    features_df = features_df.append(local_features)
# Out:
# C:\Users\Shambhavi Mishra\AppData\Local\Temp\ipykernel_19916\390151271.py:2: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for id in track_df['Id'].iteritems():
# C:\Users\Shambhavi Mishra\AppData\Local\Temp\ipykernel_19916\390151271.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_df = features_df.append(local_features)
# C:\Users\Shambhavi Mishra\AppData\Local\Temp\ipykernel_19916\390151271.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_df = features_df.append(local_features)
# C:\Users\Shambhavi Mishra\AppData\Local\Temp\ipykernel_19916\390151271.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_df = features_df.append(local_features)
# C:\Users\Shambhavi Mishra\AppData\Local\Temp\ipykernel_19916\390151271.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_df = features_df.append(local_features)
# C:\Users\Shambhavi Mishra\AppData\Local\Temp\ipykernel_19916\390151271.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_df = features_df.append(local_features)
# C:\Users\Shambhavi Mishra\AppData\Local\Temp\ipykernel_19916\390151271.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_df = features_df.append(local_features)
# C:\Users\Shambhavi Mishra\AppData\Local\Temp\ipykernel_19916\390151271.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_df = features_df.append(local_features)
# C:\Users\Shambhavi Mishra\AppData\Local\Temp\ipykernel_19916\390151271.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_df = features_df.append(local_features)
# C:\Users\Shambhavi Mishra\AppData\Local\Temp\ipykernel_19916\390151271.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_df = features_df.append(local_features)
# C:\Users\Shambhavi Mishra\AppData\Local\Temp\ipykernel_19916\390151271.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   features_df = features_df.append(local_features)

# %%
features_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.338   0.340    9   -12.049     0       0.0339      0.580000
# 0         0.564   0.932   11   -10.068     1       0.0554      0.013000
# 0         0.412   0.902    9   -11.600     1       0.4050      0.048400
# 0         0.437   0.864    4    -7.842     0       0.0904      0.396000
# 0         0.317   0.887    9    -7.292     1       0.0375      0.000582
# 0         0.476   0.717    9    -9.192     1       0.0949      0.038200
# 0         0.468   0.607    9   -11.367     1       0.0336      0.072000
# 0         0.503   0.265    2   -15.913     1       0.0333      0.943000
# 0         0.483   0.615    2    -8.538     1       0.0497      0.452000
# 0         0.402   0.691    7   -10.274     1       0.0691      0.067900
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.003200    0.1160    0.197   82.433  audio_features
# 0          0.169000    0.3490    0.619  112.937  audio_features
# 0          0.131000    0.4050    0.422   89.740  audio_features
# 0          0.031400    0.2420    0.749   81.394  audio_features
# 0          0.002580    0.0891    0.871  169.613  audio_features
# 0          0.000076    0.0818    0.753   93.584  audio_features
# 0          0.000852    0.2250    0.886   98.429  audio_features
# 0          0.045000    0.0867    0.522   78.044  audio_features
# 0          0.000414    0.0512    0.594   80.576  audio_features
# 0          0.133000    0.0955    0.206   96.950  audio_features
#
#                        id                                   uri  \
# 0  5CQ30WqJwcep0pYcV4AMNc  spotify:track:5CQ30WqJwcep0pYcV4AMNc
# 0  78lgmZwycJ3nzsdgmPPGNx  spotify:track:78lgmZwycJ3nzsdgmPPGNx
# 0  0hCB0YR03f6AmQaHbwWDe8  spotify:track:0hCB0YR03f6AmQaHbwWDe8
# 0  3qT4bUD1MaWpGrTwcvguhb  spotify:track:3qT4bUD1MaWpGrTwcvguhb
# 0  4PRGxHpCpF2yoOHYKQIEwD  spotify:track:4PRGxHpCpF2yoOHYKQIEwD
# 0  0QwZfbw26QeUoIy82Z2jYp  spotify:track:0QwZfbw26QeUoIy82Z2jYp
# 0  3MODES4TNtygekLl146Dxd  spotify:track:3MODES4TNtygekLl146Dxd
# 0  70gbuMqwNBE2Y5rkQJE9By  spotify:track:70gbuMqwNBE2Y5rkQJE9By
# 0  6Vjk8MNXpQpi0F4BefdTyq  spotify:track:6Vjk8MNXpQpi0F4BefdTyq
# 0  2eDdFHgqNJltzlvlZFVDWd  spotify:track:2eDdFHgqNJltzlvlZFVDWd
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5CQ30WqJwcep...
# 0  https://api.spotify.com/v1/tracks/78lgmZwycJ3n...
# 0  https://api.spotify.com/v1/tracks/0hCB0YR03f6A...
# 0  https://api.spotify.com/v1/tracks/3qT4bUD1MaWp...
# 0  https://api.spotify.com/v1/tracks/4PRGxHpCpF2y...
# 0  https://api.spotify.com/v1/tracks/0QwZfbw26QeU...
# 0  https://api.spotify.com/v1/tracks/3MODES4TNtyg...
# 0  https://api.spotify.com/v1/tracks/70gbuMqwNBE2...
# 0  https://api.spotify.com/v1/tracks/6Vjk8MNXpQpi...
# 0  https://api.spotify.com/v1/tracks/2eDdFHgqNJlt...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5CQ3...       482830
# 0  https://api.spotify.com/v1/audio-analysis/78lg...       146250
# 0  https://api.spotify.com/v1/audio-analysis/0hCB...       333893
# 0  https://api.spotify.com/v1/audio-analysis/3qT4...       295387
# 0  https://api.spotify.com/v1/audio-analysis/4PRG...       220561
# 0  https://api.spotify.com/v1/audio-analysis/0QwZ...       166267
# 0  https://api.spotify.com/v1/audio-analysis/3MOD...       263333
# 0  https://api.spotify.com/v1/audio-analysis/70gb...       212161
# 0  https://api.spotify.com/v1/audio-analysis/6Vjk...       517125
# 0  https://api.spotify.com/v1/audio-analysis/2eDd...       290934
#
#    time_signature
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               3
# 0               4

# %%
final_df = track_df.merge(features_df, left_on="Id", right_on="id")

# %%
final_df
# Out:
#    Item        Artist                              Album Name  \
# 0     0  Led Zeppelin  Over the Hills and Far Away - Remaster
# 1     1  Led Zeppelin  Over the Hills and Far Away - Remaster
# 2     2  Led Zeppelin  Over the Hills and Far Away - Remaster
# 3     3  Led Zeppelin  Over the Hills and Far Away - Remaster
# 4     4  Led Zeppelin  Over the Hills and Far Away - Remaster
# 5     5  Led Zeppelin  Over the Hills and Far Away - Remaster
# 6     6  Led Zeppelin  Over the Hills and Far Away - Remaster
# 7     7  Led Zeppelin  Over the Hills and Far Away - Remaster
# 8     8  Led Zeppelin  Over the Hills and Far Away - Remaster
# 9     9  Led Zeppelin  Over the Hills and Far Away - Remaster
#
#                        Id                               Song Name  \
# 0  5CQ30WqJwcep0pYcV4AMNc           Stairway to Heaven - Remaster
# 1  78lgmZwycJ3nzsdgmPPGNx               Immigrant Song - Remaster
# 2  0hCB0YR03f6AmQaHbwWDe8        Whole Lotta Love - 1990 Remaster
# 3  3qT4bUD1MaWpGrTwcvguhb                    Black Dog - Remaster
# 4  4PRGxHpCpF2yoOHYKQIEwD                Rock and Roll - Remaster
# 5  0QwZfbw26QeUoIy82Z2jYp    Good Times Bad Times - 1993 Remaster
# 6  3MODES4TNtygekLl146Dxd               Ramble On - 1990 Remaster
# 7  70gbuMqwNBE2Y5rkQJE9By          Going to California - Remaster
# 8  6Vjk8MNXpQpi0F4BefdTyq                      Kashmir - Remaster
# 9  2eDdFHgqNJltzlvlZFVDWd  Over the Hills and Far Away - Remaster
#
#   Release Date  Popularity  danceability  energy  key  ...  liveness  valence  \
# 0   1971-11-08          82         0.338   0.340    9  ...    0.1160    0.197
# 1         1970          82         0.564   0.932   11  ...    0.3490    0.619
# 2   1969-10-22          79         0.412   0.902    9  ...    0.4050    0.422
# 3   1971-11-08          76         0.437   0.864    4  ...    0.2420    0.749
# 4   1971-11-08          75         0.317   0.887    9  ...    0.0891    0.871
# 5   1969-01-12          75         0.476   0.717    9  ...    0.0818    0.753
# 6   1969-10-22          75         0.468   0.607    9  ...    0.2250    0.886
# 7   1971-11-08          73         0.503   0.265    2  ...    0.0867    0.522
# 8   1975-02-24          73         0.483   0.615    2  ...    0.0512    0.594
# 9   1973-03-28          73         0.402   0.691    7  ...    0.0955    0.206
#
#      tempo            type                      id  \
# 0   82.433  audio_features  5CQ30WqJwcep0pYcV4AMNc
# 1  112.937  audio_features  78lgmZwycJ3nzsdgmPPGNx
# 2   89.740  audio_features  0hCB0YR03f6AmQaHbwWDe8
# 3   81.394  audio_features  3qT4bUD1MaWpGrTwcvguhb
# 4  169.613  audio_features  4PRGxHpCpF2yoOHYKQIEwD
# 5   93.584  audio_features  0QwZfbw26QeUoIy82Z2jYp
# 6   98.429  audio_features  3MODES4TNtygekLl146Dxd
# 7   78.044  audio_features  70gbuMqwNBE2Y5rkQJE9By
# 8   80.576  audio_features  6Vjk8MNXpQpi0F4BefdTyq
# 9   96.950  audio_features  2eDdFHgqNJltzlvlZFVDWd
#
#                                     uri  \
# 0  spotify:track:5CQ30WqJwcep0pYcV4AMNc
# 1  spotify:track:78lgmZwycJ3nzsdgmPPGNx
# 2  spotify:track:0hCB0YR03f6AmQaHbwWDe8
# 3  spotify:track:3qT4bUD1MaWpGrTwcvguhb
# 4  spotify:track:4PRGxHpCpF2yoOHYKQIEwD
# 5  spotify:track:0QwZfbw26QeUoIy82Z2jYp
# 6  spotify:track:3MODES4TNtygekLl146Dxd
# 7  spotify:track:70gbuMqwNBE2Y5rkQJE9By
# 8  spotify:track:6Vjk8MNXpQpi0F4BefdTyq
# 9  spotify:track:2eDdFHgqNJltzlvlZFVDWd
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5CQ30WqJwcep...
# 1  https://api.spotify.com/v1/tracks/78lgmZwycJ3n...
# 2  https://api.spotify.com/v1/tracks/0hCB0YR03f6A...
# 3  https://api.spotify.com/v1/tracks/3qT4bUD1MaWp...
# 4  https://api.spotify.com/v1/tracks/4PRGxHpCpF2y...
# 5  https://api.spotify.com/v1/tracks/0QwZfbw26QeU...
# 6  https://api.spotify.com/v1/tracks/3MODES4TNtyg...
# 7  https://api.spotify.com/v1/tracks/70gbuMqwNBE2...
# 8  https://api.spotify.com/v1/tracks/6Vjk8MNXpQpi...
# 9  https://api.spotify.com/v1/tracks/2eDdFHgqNJlt...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5CQ3...      482830
# 1  https://api.spotify.com/v1/audio-analysis/78lg...      146250
# 2  https://api.spotify.com/v1/audio-analysis/0hCB...      333893
# 3  https://api.spotify.com/v1/audio-analysis/3qT4...      295387
# 4  https://api.spotify.com/v1/audio-analysis/4PRG...      220561
# 5  https://api.spotify.com/v1/audio-analysis/0QwZ...      166267
# 6  https://api.spotify.com/v1/audio-analysis/3MOD...      263333
# 7  https://api.spotify.com/v1/audio-analysis/70gb...      212161
# 8  https://api.spotify.com/v1/audio-analysis/6Vjk...      517125
# 9  https://api.spotify.com/v1/audio-analysis/2eDd...      290934
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
# 5              4
# 6              4
# 7              4
# 8              3
# 9              4
#
# [10 rows x 25 columns]

# %%
final_df_sorted = final_df.sort_values(by=['Popularity'], ascending=False)

# %%
feature_name = "danceability"

# %%
df_plot = final_df_sorted[['Artist', 'Album Name', 'Song Name', 'Release Date', 'Popularity', f'{feature_name}']]

# %%
df_plot
# Out:
#          Artist                              Album Name  \
# 0  Led Zeppelin  Over the Hills and Far Away - Remaster
# 1  Led Zeppelin  Over the Hills and Far Away - Remaster
# 2  Led Zeppelin  Over the Hills and Far Away - Remaster
# 3  Led Zeppelin  Over the Hills and Far Away - Remaster
# 4  Led Zeppelin  Over the Hills and Far Away - Remaster
# 5  Led Zeppelin  Over the Hills and Far Away - Remaster
# 6  Led Zeppelin  Over the Hills and Far Away - Remaster
# 7  Led Zeppelin  Over the Hills and Far Away - Remaster
# 8  Led Zeppelin  Over the Hills and Far Away - Remaster
# 9  Led Zeppelin  Over the Hills and Far Away - Remaster
#
#                                 Song Name Release Date  Popularity  \
# 0           Stairway to Heaven - Remaster   1971-11-08          82
# 1               Immigrant Song - Remaster         1970          82
# 2        Whole Lotta Love - 1990 Remaster   1969-10-22          79
# 3                    Black Dog - Remaster   1971-11-08          76
# 4                Rock and Roll - Remaster   1971-11-08          75
# 5    Good Times Bad Times - 1993 Remaster   1969-01-12          75
# 6               Ramble On - 1990 Remaster   1969-10-22          75
# 7          Going to California - Remaster   1971-11-08          73
# 8                      Kashmir - Remaster   1975-02-24          73
# 9  Over the Hills and Far Away - Remaster   1973-03-28          73
#
#    danceability
# 0         0.338
# 1         0.564
# 2         0.412
# 3         0.437
# 4         0.317
# 5         0.476
# 6         0.468
# 7         0.503
# 8         0.483
# 9         0.402

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.figure(figsize=(15, 6), facecolor=(.9, .9, .9))
    
x = df_plot['Song Name']
y = df_plot[feature_name]
s = df_plot['Popularity']*10
    
# color_labels = reco_df['explicit'].unique()
# rgb_values = sns.color_palette("Set1", 8)
# color_map = dict(zip(color_labels, rgb_values))

plt.scatter(x, y, s, alpha=0.7, c=df_plot[feature_name])
plt.xticks(rotation=90)
plt.legend()
# show the graph
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# !pip show altair
# Out:
# Name: altair
# Version: 5.0.1
# Summary: Vega-Altair: A declarative statistical visualization library for Python.
# Home-page:
# Author: Vega-Altair Contributors
# Author-email:
# License:
# Location: c:\programdata\anaconda3\lib\site-packages
# Requires: jinja2, jsonschema, numpy, pandas, toolz, typing-extensions
# Required-by: streamlit

# %%
import altair as alt

# %%
alt.Chart(df_plot).mark_circle().encode(
alt.X('Popularity', scale=alt.Scale(zero=False)), y=f'{feature_name}', color=alt.Color('Popularity', scale=alt.Scale(zero=False)), 
size=alt.value(200), tooltip=['Popularity', f'{feature_name}', 'Song Name', 'Album Name'])
# Out:
# alt.Chart(...)
